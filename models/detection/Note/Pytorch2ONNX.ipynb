# %%
import os
os.chdir('../')  # 更改notebook的工作路径到上一级目录

# %%
import cv2
import numpy as np

import torch
import torch.nn.functional as F
from torchvision import transforms

from model.fcos import FCOSDetector
from model.config import DefaultConfig

# %% [markdown]
# ## 模型转换之Pytorch --> ONNX

# %%
# 首先建立一个新的FCOSDetectorDeploy，目的是在forward里增加一个deploy模式
class FCOSDetectorDeploy(FCOSDetector):
    def __init__(self,mode="training",config=None):
        super().__init__(mode=mode, config=config)

    def forward(self,inputs):
        '''
        inputs
        [training] list  batch_imgs,batch_boxes,batch_classes
        [inference] img
        '''

        if self.mode=="training":
            batch_imgs,batch_boxes,batch_classes=inputs
            out=self.fcos_body(batch_imgs)
            targets=self.target_layer([out,batch_boxes,batch_classes])
            losses=self.loss_layer([out,targets])
            return losses
        elif self.mode=="inference":
            # raise NotImplementedError("no implement inference model")
            '''
            for inference mode, img should preprocessed before feeding in net
            '''
            batch_imgs=inputs
            out=self.fcos_body(batch_imgs)
            scores,classes,boxes=self.detection_head(out)
            boxes=self.clip_boxes(batch_imgs,boxes)
            return scores,classes,boxes

        # 相对于原来的FCOSDetector，增加了deploy模式，相比之前的inference，
        # deploy模式的输出是三个concat后的tensor。同样，为了将计算尽可能保留
        # 在模型内，这里的forward提前调用的sigmoid()函数
        elif self.mode=="deploy":
            out = self.fcos_body(inputs)
            # Step 1. Concat Cls Output, cls_out shape [1,20,#anchor points]
            cls_out = F.sigmoid(torch.cat([out[0][i].view(1,20,-1) for i in range(len(out[0]))], -1))
            # Step 2. Concat Cnt Output, cnt_out shape [1,1,#anchor points]
            cnt_out = F.sigmoid(torch.cat([out[1][i].view(1,1,-1) for i in range(len(out[1]))], -1))
            # Step 3. Concat Reg Output, reg_out shape [1,4,#anchor points]
            reg_out = torch.cat([out[2][i].view(1,4,-1) for i in range(len(out[2]))], -1)
            return cls_out,cnt_out,reg_out

# %%
# 以deploy模式建立一个FCOS检测器
model = FCOSDetectorDeploy(mode="deploy", config=DefaultConfig)
model = torch.nn.DataParallel(model)

# 加载训练好的模型，并开启eval()模式
model.load_state_dict(torch.load("./FCOS-PyTorch-37.2-v2/FCOS_Pure/training_dir_fp16_nogn/model_24.pth",map_location=torch.device('cpu')))
model = model.eval()

# 建立dummy_input，固定推理阶段输入图片的长和宽
inference_h = 320
inference_w = 320
dummy_input = torch.randn(1, 3, inference_h, inference_w)

# 确定模型的输入名称和输出节点名称
input_names = ['img']
output_names = ['cls', 'cnt', 'reg']

# 转换模型
name_converted = 'fcos.onnx'
torch.onnx.export(model.module, dummy_input, name_converted, verbose=True, input_names=input_names, output_names=output_names)
# Out:
# INFO: using darnet19 backbone
# /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1805: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/onnx/symbolic_helper.py:375: UserWarning: You are trying to export the model with onnx:Upsample for ONNX opset version 9. This operator might cause results to not match the expected results by PyTorch.
# ONNX's Upsample/Resize operator did not match Pytorch's Interpolation until opset 11. Attributes to determine how to transform the input were added in onnx:Resize in opset 11 to support Pytorch's behavior (like coordinate_transformation_mode and nearest_mode).
# We recommend using opset 11 and above for models using this operator.
#   "" + str(_export_onnx_opset_version) + ". "
# graph(%img : Float(1, 3, 320, 320, strides=[307200, 102400, 320, 1], requires_grad=0, device=cpu),
#       %fcos_body.fpn.prj_5.weight : Float(256, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=1, device=cpu),
#       %fcos_body.fpn.prj_5.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.fpn.prj_4.weight : Float(256, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=1, device=cpu),
#       %fcos_body.fpn.prj_4.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.fpn.prj_3.weight : Float(256, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=1, device=cpu),
#       %fcos_body.fpn.prj_3.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.fpn.conv_5.weight : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %fcos_body.fpn.conv_5.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.fpn.conv_4.weight : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %fcos_body.fpn.conv_4.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.fpn.conv_3.weight : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %fcos_body.fpn.conv_3.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.fpn.conv_out6.weight : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %fcos_body.fpn.conv_out6.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.fpn.conv_out7.weight : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %fcos_body.fpn.conv_out7.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.head.cls_conv.0.weight : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %fcos_body.head.cls_conv.0.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.head.cls_conv.2.weight : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %fcos_body.head.cls_conv.2.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.head.cls_conv.4.weight : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %fcos_body.head.cls_conv.4.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.head.cls_conv.6.weight : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %fcos_body.head.cls_conv.6.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.head.reg_conv.0.weight : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %fcos_body.head.reg_conv.0.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.head.reg_conv.2.weight : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %fcos_body.head.reg_conv.2.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.head.reg_conv.4.weight : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %fcos_body.head.reg_conv.4.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.head.reg_conv.6.weight : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %fcos_body.head.reg_conv.6.bias : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.head.cls_logits.weight : Float(20, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %fcos_body.head.cls_logits.bias : Float(20, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.head.cnt_logits.weight : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %fcos_body.head.cnt_logits.bias : Float(1, strides=[1], requires_grad=1, device=cpu),
#       %fcos_body.head.reg_pred.weight : Float(4, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %fcos_body.head.reg_pred.bias : Float(4, strides=[1], requires_grad=1, device=cpu),
#       %387 : Float(32, 3, 3, 3, strides=[27, 9, 3, 1], requires_grad=0, device=cpu),
#       %388 : Float(32, strides=[1], requires_grad=0, device=cpu),
#       %390 : Float(64, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cpu),
#       %391 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %393 : Float(128, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %394 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %396 : Float(64, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cpu),
#       %397 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %399 : Float(128, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %400 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %402 : Float(256, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %403 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %405 : Float(128, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %406 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %408 : Float(256, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %409 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %411 : Float(512, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %412 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %414 : Float(256, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cpu),
#       %415 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %417 : Float(512, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %418 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %420 : Float(256, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cpu),
#       %421 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %423 : Float(512, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %424 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %426 : Float(1024, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %427 : Float(1024, strides=[1], requires_grad=0, device=cpu),
#       %429 : Float(512, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cpu),
#       %430 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %432 : Float(1024, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %433 : Float(1024, strides=[1], requires_grad=0, device=cpu),
#       %435 : Float(512, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cpu),
#       %436 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %438 : Float(1024, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %439 : Float(1024, strides=[1], requires_grad=0, device=cpu)):
#   %386 : Float(1, 32, 320, 320, strides=[3276800, 102400, 320, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%img, %387, %388)
#   %149 : Float(1, 32, 320, 320, strides=[3276800, 102400, 320, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%386) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %150 : Float(1, 32, 160, 160, strides=[819200, 25600, 160, 1], requires_grad=1, device=cpu) = onnx::MaxPool[kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%149) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:718:0
#   %389 : Float(1, 64, 160, 160, strides=[1638400, 25600, 160, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%150, %390, %391)
#   %153 : Float(1, 64, 160, 160, strides=[1638400, 25600, 160, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%389) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %154 : Float(1, 64, 80, 80, strides=[409600, 6400, 80, 1], requires_grad=1, device=cpu) = onnx::MaxPool[kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%153) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:718:0
#   %392 : Float(1, 128, 80, 80, strides=[819200, 6400, 80, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%154, %393, %394)
#   %157 : Float(1, 128, 80, 80, strides=[819200, 6400, 80, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%392) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %395 : Float(1, 64, 80, 80, strides=[409600, 6400, 80, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%157, %396, %397)
#   %160 : Float(1, 64, 80, 80, strides=[409600, 6400, 80, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%395) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %398 : Float(1, 128, 80, 80, strides=[819200, 6400, 80, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%160, %399, %400)
#   %163 : Float(1, 128, 80, 80, strides=[819200, 6400, 80, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%398) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %164 : Float(1, 128, 40, 40, strides=[204800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::MaxPool[kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%163) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:718:0
#   %401 : Float(1, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%164, %402, %403)
#   %167 : Float(1, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%401) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %404 : Float(1, 128, 40, 40, strides=[204800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%167, %405, %406)
#   %170 : Float(1, 128, 40, 40, strides=[204800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%404) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %407 : Float(1, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%170, %408, %409)
#   %173 : Float(1, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%407) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %174 : Float(1, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::MaxPool[kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%173) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:718:0
#   %410 : Float(1, 512, 20, 20, strides=[204800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%174, %411, %412)
#   %177 : Float(1, 512, 20, 20, strides=[204800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%410) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %413 : Float(1, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%177, %414, %415)
#   %180 : Float(1, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%413) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %416 : Float(1, 512, 20, 20, strides=[204800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%180, %417, %418)
#   %183 : Float(1, 512, 20, 20, strides=[204800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%416) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %419 : Float(1, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%183, %420, %421)
#   %186 : Float(1, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%419) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %422 : Float(1, 512, 20, 20, strides=[204800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%186, %423, %424)
#   %189 : Float(1, 512, 20, 20, strides=[204800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%422) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %190 : Float(1, 512, 10, 10, strides=[51200, 100, 10, 1], requires_grad=1, device=cpu) = onnx::MaxPool[kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%189) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:718:0
#   %425 : Float(1, 1024, 10, 10, strides=[102400, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%190, %426, %427)
#   %193 : Float(1, 1024, 10, 10, strides=[102400, 100, 10, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%425) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %428 : Float(1, 512, 10, 10, strides=[51200, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%193, %429, %430)
#   %196 : Float(1, 512, 10, 10, strides=[51200, 100, 10, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%428) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %431 : Float(1, 1024, 10, 10, strides=[102400, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%196, %432, %433)
#   %199 : Float(1, 1024, 10, 10, strides=[102400, 100, 10, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%431) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %434 : Float(1, 512, 10, 10, strides=[51200, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%199, %435, %436)
#   %202 : Float(1, 512, 10, 10, strides=[51200, 100, 10, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%434) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %437 : Float(1, 1024, 10, 10, strides=[102400, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%202, %438, %439)
#   %205 : Float(1, 1024, 10, 10, strides=[102400, 100, 10, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%437) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1472:0
#   %206 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%205, %fcos_body.fpn.prj_5.weight, %fcos_body.fpn.prj_5.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %207 : Float(1, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%189, %fcos_body.fpn.prj_4.weight, %fcos_body.fpn.prj_4.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %208 : Float(1, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%173, %fcos_body.fpn.prj_3.weight, %fcos_body.fpn.prj_3.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %209 : Long(4, strides=[1], device=cpu) = onnx::Shape(%189)
#   %210 : Long(device=cpu) = onnx::Constant[value={2}]()
#   %211 : Long(device=cpu) = onnx::Gather[axis=0](%209, %210) # /Users/calebge/Desktop/personal/深度之眼/实时行人检测第二期/FCOS-PyTorch-37.2-v2/FCOS_Pure/model/fpn_neck.py:88:0
#   %212 : Long(4, strides=[1], device=cpu) = onnx::Shape(%189)
#   %213 : Long(device=cpu) = onnx::Constant[value={3}]()
#   %214 : Long(device=cpu) = onnx::Gather[axis=0](%212, %213) # /Users/calebge/Desktop/personal/深度之眼/实时行人检测第二期/FCOS-PyTorch-37.2-v2/FCOS_Pure/model/fpn_neck.py:88:0
#   %215 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%211)
#   %216 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%214)
#   %217 : Long(2, strides=[1], device=cpu) = onnx::Concat[axis=0](%215, %216)
#   %218 : Float(2, strides=[1], device=cpu) = onnx::Constant[value= 1  1 [ CPUFloatType{2} ]]()
#   %219 : Float(2, strides=[1], device=cpu) = onnx::Cast[to=1](%217)
#   %220 : Long(4, strides=[1], device=cpu) = onnx::Shape(%206)
#   %221 : Long(2, strides=[1], device=cpu) = onnx::Slice[axes=[0], ends=[9223372036854775807], starts=[2]](%220)
#   %222 : Float(2, strides=[1], device=cpu) = onnx::Cast[to=1](%221)
#   %223 : Float(2, strides=[1], device=cpu) = onnx::Div(%219, %222)
#   %224 : Float(4, strides=[1], device=cpu) = onnx::Concat[axis=0](%218, %223)
#   %225 : Float(*, *, *, *, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Upsample[mode="nearest"](%206, %224) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:3690:0
#   %226 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Add(%207, %225) # /Users/calebge/Desktop/personal/深度之眼/实时行人检测第二期/FCOS-PyTorch-37.2-v2/FCOS_Pure/model/fpn_neck.py:103:0
#   %227 : Long(4, strides=[1], device=cpu) = onnx::Shape(%173)
#   %228 : Long(device=cpu) = onnx::Constant[value={2}]()
#   %229 : Long(device=cpu) = onnx::Gather[axis=0](%227, %228) # /Users/calebge/Desktop/personal/深度之眼/实时行人检测第二期/FCOS-PyTorch-37.2-v2/FCOS_Pure/model/fpn_neck.py:88:0
#   %230 : Long(4, strides=[1], device=cpu) = onnx::Shape(%173)
#   %231 : Long(device=cpu) = onnx::Constant[value={3}]()
#   %232 : Long(device=cpu) = onnx::Gather[axis=0](%230, %231) # /Users/calebge/Desktop/personal/深度之眼/实时行人检测第二期/FCOS-PyTorch-37.2-v2/FCOS_Pure/model/fpn_neck.py:88:0
#   %233 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%229)
#   %234 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%232)
#   %235 : Long(2, strides=[1], device=cpu) = onnx::Concat[axis=0](%233, %234)
#   %236 : Float(2, strides=[1], device=cpu) = onnx::Constant[value= 1  1 [ CPUFloatType{2} ]]()
#   %237 : Float(2, strides=[1], device=cpu) = onnx::Cast[to=1](%235)
#   %238 : Long(4, strides=[1], device=cpu) = onnx::Shape(%226)
#   %239 : Long(2, strides=[1], device=cpu) = onnx::Slice[axes=[0], ends=[9223372036854775807], starts=[2]](%238)
#   %240 : Float(2, strides=[1], device=cpu) = onnx::Cast[to=1](%239)
#   %241 : Float(2, strides=[1], device=cpu) = onnx::Div(%237, %240)
#   %242 : Float(4, strides=[1], device=cpu) = onnx::Concat[axis=0](%236, %241)
#   %243 : Float(*, *, *, *, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Upsample[mode="nearest"](%226, %242) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:3690:0
#   %244 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Add(%208, %243) # /Users/calebge/Desktop/personal/深度之眼/实时行人检测第二期/FCOS-PyTorch-37.2-v2/FCOS_Pure/model/fpn_neck.py:104:0
#   %245 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%244, %fcos_body.fpn.conv_3.weight, %fcos_body.fpn.conv_3.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %246 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%226, %fcos_body.fpn.conv_4.weight, %fcos_body.fpn.conv_4.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %247 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%206, %fcos_body.fpn.conv_5.weight, %fcos_body.fpn.conv_5.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %248 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%247, %fcos_body.fpn.conv_out6.weight, %fcos_body.fpn.conv_out6.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %249 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Relu(%248) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1298:0
#   %250 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%249, %fcos_body.fpn.conv_out7.weight, %fcos_body.fpn.conv_out7.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %251 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%245, %fcos_body.head.cls_conv.0.weight, %fcos_body.head.cls_conv.0.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %252 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Relu(%251) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %253 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%252, %fcos_body.head.cls_conv.2.weight, %fcos_body.head.cls_conv.2.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %254 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Relu(%253) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %255 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%254, %fcos_body.head.cls_conv.4.weight, %fcos_body.head.cls_conv.4.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %256 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Relu(%255) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %257 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%256, %fcos_body.head.cls_conv.6.weight, %fcos_body.head.cls_conv.6.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %258 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Relu(%257) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %259 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%245, %fcos_body.head.reg_conv.0.weight, %fcos_body.head.reg_conv.0.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %260 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Relu(%259) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %261 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%260, %fcos_body.head.reg_conv.2.weight, %fcos_body.head.reg_conv.2.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %262 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Relu(%261) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %263 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%262, %fcos_body.head.reg_conv.4.weight, %fcos_body.head.reg_conv.4.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %264 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Relu(%263) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %265 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%264, %fcos_body.head.reg_conv.6.weight, %fcos_body.head.reg_conv.6.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %266 : Float(*, 256, 40, 40, strides=[409600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Relu(%265) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %267 : Float(*, 20, 40, 40, strides=[32000, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%258, %fcos_body.head.cls_logits.weight, %fcos_body.head.cls_logits.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %268 : Float(*, 1, 40, 40, strides=[1600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%266, %fcos_body.head.cnt_logits.weight, %fcos_body.head.cnt_logits.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %269 : Float(*, 4, 40, 40, strides=[6400, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%266, %fcos_body.head.reg_pred.weight, %fcos_body.head.reg_pred.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %270 : Float(*, 4, 40, 40, strides=[6400, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Exp(%269) # /Users/calebge/Desktop/personal/深度之眼/实时行人检测第二期/FCOS-PyTorch-37.2-v2/FCOS_Pure/model/head.py:75:0
#   %271 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%246, %fcos_body.head.cls_conv.0.weight, %fcos_body.head.cls_conv.0.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %272 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Relu(%271) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %273 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%272, %fcos_body.head.cls_conv.2.weight, %fcos_body.head.cls_conv.2.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %274 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Relu(%273) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %275 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%274, %fcos_body.head.cls_conv.4.weight, %fcos_body.head.cls_conv.4.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %276 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Relu(%275) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %277 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%276, %fcos_body.head.cls_conv.6.weight, %fcos_body.head.cls_conv.6.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %278 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Relu(%277) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %279 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%246, %fcos_body.head.reg_conv.0.weight, %fcos_body.head.reg_conv.0.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %280 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Relu(%279) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %281 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%280, %fcos_body.head.reg_conv.2.weight, %fcos_body.head.reg_conv.2.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %282 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Relu(%281) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %283 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%282, %fcos_body.head.reg_conv.4.weight, %fcos_body.head.reg_conv.4.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %284 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Relu(%283) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %285 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%284, %fcos_body.head.reg_conv.6.weight, %fcos_body.head.reg_conv.6.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %286 : Float(*, 256, 20, 20, strides=[102400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Relu(%285) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %287 : Float(*, 20, 20, 20, strides=[8000, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%278, %fcos_body.head.cls_logits.weight, %fcos_body.head.cls_logits.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %288 : Float(*, 1, 20, 20, strides=[400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%286, %fcos_body.head.cnt_logits.weight, %fcos_body.head.cnt_logits.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %289 : Float(*, 4, 20, 20, strides=[1600, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%286, %fcos_body.head.reg_pred.weight, %fcos_body.head.reg_pred.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %290 : Float(*, 4, 20, 20, strides=[1600, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Exp(%289) # /Users/calebge/Desktop/personal/深度之眼/实时行人检测第二期/FCOS-PyTorch-37.2-v2/FCOS_Pure/model/head.py:75:0
#   %291 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%247, %fcos_body.head.cls_conv.0.weight, %fcos_body.head.cls_conv.0.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %292 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Relu(%291) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %293 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%292, %fcos_body.head.cls_conv.2.weight, %fcos_body.head.cls_conv.2.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %294 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Relu(%293) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %295 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%294, %fcos_body.head.cls_conv.4.weight, %fcos_body.head.cls_conv.4.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %296 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Relu(%295) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %297 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%296, %fcos_body.head.cls_conv.6.weight, %fcos_body.head.cls_conv.6.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %298 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Relu(%297) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %299 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%247, %fcos_body.head.reg_conv.0.weight, %fcos_body.head.reg_conv.0.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %300 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Relu(%299) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %301 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%300, %fcos_body.head.reg_conv.2.weight, %fcos_body.head.reg_conv.2.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %302 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Relu(%301) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %303 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%302, %fcos_body.head.reg_conv.4.weight, %fcos_body.head.reg_conv.4.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %304 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Relu(%303) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %305 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%304, %fcos_body.head.reg_conv.6.weight, %fcos_body.head.reg_conv.6.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %306 : Float(1, 256, 10, 10, strides=[25600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Relu(%305) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %307 : Float(1, 20, 10, 10, strides=[2000, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%298, %fcos_body.head.cls_logits.weight, %fcos_body.head.cls_logits.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %308 : Float(1, 1, 10, 10, strides=[100, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%306, %fcos_body.head.cnt_logits.weight, %fcos_body.head.cnt_logits.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %309 : Float(1, 4, 10, 10, strides=[400, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%306, %fcos_body.head.reg_pred.weight, %fcos_body.head.reg_pred.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %310 : Float(1, 4, 10, 10, strides=[400, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Exp(%309) # /Users/calebge/Desktop/personal/深度之眼/实时行人检测第二期/FCOS-PyTorch-37.2-v2/FCOS_Pure/model/head.py:75:0
#   %311 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%248, %fcos_body.head.cls_conv.0.weight, %fcos_body.head.cls_conv.0.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %312 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Relu(%311) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %313 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%312, %fcos_body.head.cls_conv.2.weight, %fcos_body.head.cls_conv.2.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %314 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Relu(%313) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %315 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%314, %fcos_body.head.cls_conv.4.weight, %fcos_body.head.cls_conv.4.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %316 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Relu(%315) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %317 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%316, %fcos_body.head.cls_conv.6.weight, %fcos_body.head.cls_conv.6.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %318 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Relu(%317) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %319 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%248, %fcos_body.head.reg_conv.0.weight, %fcos_body.head.reg_conv.0.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %320 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Relu(%319) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %321 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%320, %fcos_body.head.reg_conv.2.weight, %fcos_body.head.reg_conv.2.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %322 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Relu(%321) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %323 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%322, %fcos_body.head.reg_conv.4.weight, %fcos_body.head.reg_conv.4.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %324 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Relu(%323) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %325 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%324, %fcos_body.head.reg_conv.6.weight, %fcos_body.head.reg_conv.6.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %326 : Float(1, 256, 5, 5, strides=[6400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Relu(%325) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %327 : Float(1, 20, 5, 5, strides=[500, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%318, %fcos_body.head.cls_logits.weight, %fcos_body.head.cls_logits.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %328 : Float(1, 1, 5, 5, strides=[25, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%326, %fcos_body.head.cnt_logits.weight, %fcos_body.head.cnt_logits.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %329 : Float(1, 4, 5, 5, strides=[100, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%326, %fcos_body.head.reg_pred.weight, %fcos_body.head.reg_pred.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %330 : Float(1, 4, 5, 5, strides=[100, 25, 5, 1], requires_grad=1, device=cpu) = onnx::Exp(%329) # /Users/calebge/Desktop/personal/深度之眼/实时行人检测第二期/FCOS-PyTorch-37.2-v2/FCOS_Pure/model/head.py:75:0
#   %331 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%250, %fcos_body.head.cls_conv.0.weight, %fcos_body.head.cls_conv.0.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %332 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Relu(%331) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %333 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%332, %fcos_body.head.cls_conv.2.weight, %fcos_body.head.cls_conv.2.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %334 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Relu(%333) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %335 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%334, %fcos_body.head.cls_conv.4.weight, %fcos_body.head.cls_conv.4.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %336 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Relu(%335) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %337 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%336, %fcos_body.head.cls_conv.6.weight, %fcos_body.head.cls_conv.6.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %338 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Relu(%337) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %339 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%250, %fcos_body.head.reg_conv.0.weight, %fcos_body.head.reg_conv.0.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %340 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Relu(%339) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %341 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%340, %fcos_body.head.reg_conv.2.weight, %fcos_body.head.reg_conv.2.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %342 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Relu(%341) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %343 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%342, %fcos_body.head.reg_conv.4.weight, %fcos_body.head.reg_conv.4.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %344 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Relu(%343) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %345 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%344, %fcos_body.head.reg_conv.6.weight, %fcos_body.head.reg_conv.6.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %346 : Float(1, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Relu(%345) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1296:0
#   %347 : Float(1, 20, 3, 3, strides=[180, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%338, %fcos_body.head.cls_logits.weight, %fcos_body.head.cls_logits.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %348 : Float(1, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%346, %fcos_body.head.cnt_logits.weight, %fcos_body.head.cnt_logits.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %349 : Float(1, 4, 3, 3, strides=[36, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%346, %fcos_body.head.reg_pred.weight, %fcos_body.head.reg_pred.bias) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py:440:0
#   %350 : Float(1, 4, 3, 3, strides=[36, 9, 3, 1], requires_grad=1, device=cpu) = onnx::Exp(%349) # /Users/calebge/Desktop/personal/深度之眼/实时行人检测第二期/FCOS-PyTorch-37.2-v2/FCOS_Pure/model/head.py:75:0
#   %351 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=  1  20  -1 [ CPULongType{3} ]]()
#   %352 : Float(1, 20, *, strides=[32000, 1600, 1], requires_grad=1, device=cpu) = onnx::Reshape(%267, %351) # <ipython-input-11-08d83c799781>:36:0
#   %353 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=  1  20  -1 [ CPULongType{3} ]]()
#   %354 : Float(1, 20, *, strides=[8000, 400, 1], requires_grad=1, device=cpu) = onnx::Reshape(%287, %353) # <ipython-input-11-08d83c799781>:36:0
#   %355 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=  1  20  -1 [ CPULongType{3} ]]()
#   %356 : Float(1, 20, 100, strides=[2000, 100, 1], requires_grad=1, device=cpu) = onnx::Reshape(%307, %355) # <ipython-input-11-08d83c799781>:36:0
#   %357 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=  1  20  -1 [ CPULongType{3} ]]()
#   %358 : Float(1, 20, 25, strides=[500, 25, 1], requires_grad=1, device=cpu) = onnx::Reshape(%327, %357) # <ipython-input-11-08d83c799781>:36:0
#   %359 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=  1  20  -1 [ CPULongType{3} ]]()
#   %360 : Float(1, 20, 9, strides=[180, 9, 1], requires_grad=1, device=cpu) = onnx::Reshape(%347, %359) # <ipython-input-11-08d83c799781>:36:0
#   %361 : Float(1, 20, 2134, strides=[42680, 2134, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=-1](%352, %354, %356, %358, %360) # <ipython-input-11-08d83c799781>:36:0
#   %cls : Float(1, 20, 2134, strides=[42680, 2134, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%361) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1806:0
#   %363 : Long(3, strides=[1], device=cpu) = onnx::Constant[value= 1  1 -1 [ CPULongType{3} ]]()
#   %364 : Float(1, 1, *, strides=[1600, 1600, 1], requires_grad=1, device=cpu) = onnx::Reshape(%268, %363) # <ipython-input-11-08d83c799781>:38:0
#   %365 : Long(3, strides=[1], device=cpu) = onnx::Constant[value= 1  1 -1 [ CPULongType{3} ]]()
#   %366 : Float(1, 1, *, strides=[400, 400, 1], requires_grad=1, device=cpu) = onnx::Reshape(%288, %365) # <ipython-input-11-08d83c799781>:38:0
#   %367 : Long(3, strides=[1], device=cpu) = onnx::Constant[value= 1  1 -1 [ CPULongType{3} ]]()
#   %368 : Float(1, 1, 100, strides=[100, 100, 1], requires_grad=1, device=cpu) = onnx::Reshape(%308, %367) # <ipython-input-11-08d83c799781>:38:0
#   %369 : Long(3, strides=[1], device=cpu) = onnx::Constant[value= 1  1 -1 [ CPULongType{3} ]]()
#   %370 : Float(1, 1, 25, strides=[25, 25, 1], requires_grad=1, device=cpu) = onnx::Reshape(%328, %369) # <ipython-input-11-08d83c799781>:38:0
#   %371 : Long(3, strides=[1], device=cpu) = onnx::Constant[value= 1  1 -1 [ CPULongType{3} ]]()
#   %372 : Float(1, 1, 9, strides=[9, 9, 1], requires_grad=1, device=cpu) = onnx::Reshape(%348, %371) # <ipython-input-11-08d83c799781>:38:0
#   %373 : Float(1, 1, 2134, strides=[2134, 2134, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=-1](%364, %366, %368, %370, %372) # <ipython-input-11-08d83c799781>:38:0
#   %cnt : Float(1, 1, 2134, strides=[2134, 2134, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%373) # /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1806:0
#   %375 : Long(3, strides=[1], device=cpu) = onnx::Constant[value= 1  4 -1 [ CPULongType{3} ]]()
#   %376 : Float(1, 4, *, strides=[6400, 1600, 1], requires_grad=1, device=cpu) = onnx::Reshape(%270, %375) # <ipython-input-11-08d83c799781>:40:0
#   %377 : Long(3, strides=[1], device=cpu) = onnx::Constant[value= 1  4 -1 [ CPULongType{3} ]]()
#   %378 : Float(1, 4, *, strides=[1600, 400, 1], requires_grad=1, device=cpu) = onnx::Reshape(%290, %377) # <ipython-input-11-08d83c799781>:40:0
#   %379 : Long(3, strides=[1], device=cpu) = onnx::Constant[value= 1  4 -1 [ CPULongType{3} ]]()
#   %380 : Float(1, 4, 100, strides=[400, 100, 1], requires_grad=1, device=cpu) = onnx::Reshape(%310, %379) # <ipython-input-11-08d83c799781>:40:0
#   %381 : Long(3, strides=[1], device=cpu) = onnx::Constant[value= 1  4 -1 [ CPULongType{3} ]]()
#   %382 : Float(1, 4, 25, strides=[100, 25, 1], requires_grad=1, device=cpu) = onnx::Reshape(%330, %381) # <ipython-input-11-08d83c799781>:40:0
#   %383 : Long(3, strides=[1], device=cpu) = onnx::Constant[value= 1  4 -1 [ CPULongType{3} ]]()
#   %384 : Float(1, 4, 9, strides=[36, 9, 1], requires_grad=1, device=cpu) = onnx::Reshape(%350, %383) # <ipython-input-11-08d83c799781>:40:0
#   %reg : Float(1, 4, 2134, strides=[8536, 2134, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=-1](%376, %378, %380, %382, %384) # <ipython-input-11-08d83c799781>:40:0
#   return (%cls, %cnt, %reg)

# %% [markdown]
# ## 验证模型转换精度1--用原始的Pytorch推理图片

# %%
# 读取图片
img_name = 'test_images/000004.jpg'
img = cv2.imread(img_name)

# 需要将模型转换到float32
img = cv2.resize(img, (320,320)).astype('float32')

# 将模型从[320,320,3]变成[1,3,320,320]的推理形状
img = np.transpose(img, (2,0,1))[None,...]
img = torch.tensor(img)

# 以deploy模式建立FCOS检测器
model = FCOSDetectorDeploy(mode="deploy", config=DefaultConfig)
model = torch.nn.DataParallel(model)

# 加载预训练模型
model.load_state_dict(torch.load("./training_dir_fp16_nogn/model_24.pth",map_location=torch.device('cpu')))
model = model.eval()

# 拿到分类，中心度和回归的输出，并打印回归的输出方便与onnx的结果做对比
with torch.no_grad():
    cls1, cnt1, reg1 = model(img)
    print(reg1)
# Out:
# INFO: using darnet19 backbone
# tensor([[[3.5129e+02, 1.0395e+04, 8.7255e+03,  ..., 1.8458e+02,
#           7.5282e+02, 9.8308e+02],
#          [1.3531e+02, 3.2338e+02, 8.0767e+02,  ..., 6.3049e+05,
#           2.0588e+05, 5.4898e+02],
#          [1.4481e+03, 3.8759e+04, 7.5060e+05,  ..., 3.0634e+03,
#           1.7337e+02, 4.6023e+00],
#          [2.1421e+01, 3.4048e+00, 1.0136e+00,  ..., 1.4374e+02,
#           1.3487e+01, 4.3831e+00]]])
# /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1386: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %% [markdown]
# ## 验证模型转换精度2--用ONNX推理图片

# %%
# 导入所需的onnxruntime包
# 如果没有这个包，则安装: pip install onnxruntime
import onnxruntime

# %%
# 读取图片
img_name = 'test_images/000004.jpg'
img = cv2.imread(img_name)

# 需要将模型转换到float32，否则无法推理
img = cv2.resize(img, (320,320)).astype('float32')

# 将模型从[320,320,3]变成[1,3,320,320]的推理格式
img = np.transpose(img, (2,0,1))[None,...]

# 使用onnxruntime加载转换好的fcos检测器
sess = onnxruntime.InferenceSession(name_converted, None)

# 使用onnxruntime进行推理，并打印回归输出
(cls2, cnt2, reg2) = sess.run(None, {'img': img})
print(reg2)
# Out:
# [[[3.51289093e+02 1.03950938e+04 8.72563379e+03 ... 1.84585175e+02
#    7.52820618e+02 9.83078430e+02]
#   [1.35305420e+02 3.23380798e+02 8.07670959e+02 ... 6.30485938e+05
#    2.05873422e+05 5.48978455e+02]
#   [1.44809155e+03 3.87590586e+04 7.50608750e+05 ... 3.06335059e+03
#    1.73369644e+02 4.60233307e+00]
#   [2.14211693e+01 3.40483952e+00 1.01360846e+00 ... 1.43739243e+02
#    1.34865055e+01 4.38306761e+00]]]

# %%
# 观察Pytorch到onnx在回归输出上的转换误差
reg1.numpy() - reg2
# Out:
# array([[[ 4.8828125e-04, -4.8828125e-02, -9.9609375e-02, ...,
#          -2.5939941e-04,  3.2348633e-03, -2.3803711e-03],
#         [ 7.7819824e-04, -6.4086914e-04, -4.6386719e-03, ...,
#           3.0000000e+00,  2.1718750e+00, -4.8828125e-04],
#         [ 5.4931641e-03, -1.8750000e-01, -7.8750000e+00, ...,
#           8.7890625e-03,  5.7983398e-04,  2.3841858e-06],
#         [ 9.1552734e-05,  9.5367432e-06,  4.0531158e-06, ...,
#           6.2561035e-04, -3.8146973e-06, -2.3841858e-06]]], dtype=float32)
